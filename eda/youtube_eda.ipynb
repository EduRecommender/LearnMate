# %%
import pandas as pd

# %%
df = pd.read_csv('../raw_data/isma_youtube_videos.csv')
df
# Out:
#                                                  Title              Channel  \
# 0        30 Years of Business Knowledge in 2hrs 26mins         Simon Squibb
# 1    6 Tips on Being a Successful Entrepreneur | Jo...                  TED
# 2    How To Start a Business - Step by Step Guide f...       ClearValue Tax
# 3                 5 Steps to Start Your First Business           Ali Abdaal
# 4     33Yrs of Business Experience in 4hrs FULL COURSE     CEO Entrepreneur
# ..                                                 ...                  ...
# 795                                 Precalculus Course     freeCodeCamp.org
# 796            Understand Chain Rule in 39.97 Seconds!  Yeah Math Is Boring
# 797  Derivative as a concept | Derivatives introduc...         Khan Academy
# 798   Integration rundown by Goggins (quick AI lesson)               Onlock
# 799  Differential Calculus- Explained in Just 4 Min...    The Science Biome
#
# ...

# %%
df.shape
# Out:
# (800, 12)
